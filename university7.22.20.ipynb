# %%
import pandas as pd
import numpy as np
import xlrd
import matplotlib.pyplot as plt
import seaborn as sns

# ro be able to see more rows when looking at the data you can use the below 
pd.options.display.max_rows = 999


# git remote add origin https://github.com/MarilynSasha/university.git
# git push -u origin master

# %%
university = pd.read_csv('https://s3-us-west-2.amazonaws.com/learn-assets.galvanize.com/gSchool/ds-curriculum/sql-block/universities.csv')

# %%
university
# Out:
#                                                    name  \
# 0               A T Still University of Health Sciences
# 1                          Abilene Christian University
# 2                  Abraham Baldwin Agricultural College
# 3                                       Academy College
# 4                  Academy for Five Element Acupuncture
# ...                                                 ...
# 2902  Yo San University of Traditional Chinese Medicine
# 2903                                       York College
# 2904                          York College Pennsylvania
# 2905                        Youngstown State University
# 2906                                 Zion Bible College
#
#                                                 address  \
# 0           800 W Jefferson, Kirksville, Missouri 63501
# 1               1600 Campus Court, Abilene, Texas 79699
# 2            2802 Moore Hwy, Tifton, Georgia 31793-2601
# 3     1101 E. 78th Street, Suite 100, Minneapolis, M...
# ...

# %%
university.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2907 entries, 0 to 2906
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   name     2907 non-null   object
#  1   address  2907 non-null   object
#  2   Website  2822 non-null   object
#  3   Type     2907 non-null   object
#  4   Size     2829 non-null   float64
# dtypes: float64(1), object(4)
# memory usage: 113.7+ KB

# %%
# mean
utype = university.groupby('Type')
utype2 = utype.mean()
utype2
# Out:
#                                                             Size
# Type
# 4-year, Private for-profit                           3504.501859
# 4-year, Private not-for-profit                       2399.885696
# 4-year, Public                                      11478.913765
# 4-year, primarily associate's, Private for-profit     934.380597
# 4-year, primarily associate's, Private not-for-...   1129.413793
# 4-year, primarily associate's, Public                6889.366197

# %%
# median
utype3 = utype.median()
utype3
# Out:
#                                                       Size
# Type
# 4-year, Private for-profit                           730.0
# 4-year, Private not-for-profit                      1206.0
# 4-year, Public                                      7669.0
# 4-year, primarily associate's, Private for-profit    564.5
# 4-year, primarily associate's, Private not-for-...   768.0
# 4-year, primarily associate's, Public               3558.0

# %%
# order by average size 
utype2.sort_values(by=['Size'])
# Out:
#                                                             Size
# Type
# 4-year, primarily associate's, Private for-profit     934.380597
# 4-year, primarily associate's, Private not-for-...   1129.413793
# 4-year, Private not-for-profit                       2399.885696
# 4-year, Private for-profit                           3504.501859
# 4-year, primarily associate's, Public                6889.366197
# 4-year, Public                                      11478.913765

# %%
# putting together mean and median by type and sorts values mean asc

utype2.join(utype3, how='inner', lsuffix= 'mean', rsuffix = 'median').sort_values(by=['Sizemean'])
# Out:
#                                                         Sizemean  Sizemedian
# Type
# 4-year, primarily associate's, Private for-profit     934.380597       564.5
# 4-year, primarily associate's, Private not-for-...   1129.413793       768.0
# 4-year, Private not-for-profit                       2399.885696      1206.0
# 4-year, Private for-profit                           3504.501859       730.0
# 4-year, primarily associate's, Public                6889.366197      3558.0
# 4-year, Public                                      11478.913765      7669.0

# %%
# new columns 
# split address 
# private or public 
# primary associates 1=yes, 0=no

# %%
# references :
# names = data['name']
# type(names), names

# names = names.str.split(',', expand=True) #expand puts results into two separate columns
# names

# %%
# split address 
addresses = university['address']
type(addresses), addresses
# Out:
# (pandas.core.series.Series,
#  0             800 W Jefferson, Kirksville, Missouri 63501
#  1                 1600 Campus Court, Abilene, Texas 79699
#  2              2802 Moore Hwy, Tifton, Georgia 31793-2601
#  3       1101 E. 78th Street, Suite 100, Minneapolis, M...
#  4              305 SE 2nd Ave, Gainesville, Florida 32601
#                                ...
#  2902    13315 W. Washington Boulevard, Los Angeles, Ca...
#  2903             1125 E 8th St, York, Nebraska 68467-2699
#  2904       Country Club Rd, York, Pennsylvania 17403-3651
#  2905    One University Plaza, Youngstown, Ohio 44555-0001
#  2906    320 South Main Street, Haverhill, Massachusett...
#  Name: address, Length: 2907, dtype: object)

# %%
# create new columns IN the university dataframe and assigning them 
# rsplit function splits from right hand instead of the left 
# this splits twice on the first two commas

university[['street', 'city', "state"]] = university.address.str.rsplit(',',2, expand=True)
university
# Out:
#                                                    name  \
# 0               A T Still University of Health Sciences
# 1                          Abilene Christian University
# 2                  Abraham Baldwin Agricultural College
# 3                                       Academy College
# 4                  Academy for Five Element Acupuncture
# ...                                                 ...
# 2902  Yo San University of Traditional Chinese Medicine
# 2903                                       York College
# 2904                          York College Pennsylvania
# 2905                        Youngstown State University
# 2906                                 Zion Bible College
#
#                                                 address  \
# 0           800 W Jefferson, Kirksville, Missouri 63501
# 1               1600 Campus Court, Abilene, Texas 79699
# 2            2802 Moore Hwy, Tifton, Georgia 31793-2601
# 3     1101 E. 78th Street, Suite 100, Minneapolis, M...
# ...

# %%
# split state column on a space 
university[["state2", "zip"]] = university.state.str.rsplit(' ',1, expand=True)
university
# Out:
#                                                    name  \
# 0               A T Still University of Health Sciences
# 1                          Abilene Christian University
# 2                  Abraham Baldwin Agricultural College
# 3                                       Academy College
# 4                  Academy for Five Element Acupuncture
# ...                                                 ...
# 2902  Yo San University of Traditional Chinese Medicine
# 2903                                       York College
# 2904                          York College Pennsylvania
# 2905                        Youngstown State University
# 2906                                 Zion Bible College
#
#                                                 address  \
# 0           800 W Jefferson, Kirksville, Missouri 63501
# 1               1600 Campus Court, Abilene, Texas 79699
# 2            2802 Moore Hwy, Tifton, Georgia 31793-2601
# 3     1101 E. 78th Street, Suite 100, Minneapolis, M...
# ...

# %%
adresses2 = addresses[2].str.split(" ", expand=True)
adresses2
# Out:
#      0               1           2     3     4     5
# 0             Missouri       63501  None  None  None
# 1                Texas       79699  None  None  None
# 2              Georgia  31793-2601  None  None  None
# 3          Minneapolis        None  None  None  None
# 4              Florida       32601  None  None  None
# ...  ..            ...         ...   ...   ...   ...
# 2902        California       90066  None  None  None
# 2903          Nebraska  68467-2699  None  None  None
# 2904      Pennsylvania  17403-3651  None  None  None
# 2905              Ohio  44555-0001  None  None  None
# 2906     Massachusetts       01835  None  None  None
#
# [2907 rows x 6 columns]

# %%
# rename column in addresses2
adresses2 = adresses2.rename(columns={0:'nnon',1:'state', 2:'zip', 3:'non1', 4:'non2', 5:'non3'})
adresses2
# Out:
#      nnon          state         zip  non1  non2  non3
# 0               Missouri       63501  None  None  None
# 1                  Texas       79699  None  None  None
# 2                Georgia  31793-2601  None  None  None
# 3            Minneapolis        None  None  None  None
# 4                Florida       32601  None  None  None
# ...   ...            ...         ...   ...   ...   ...
# 2902          California       90066  None  None  None
# 2903            Nebraska  68467-2699  None  None  None
# 2904        Pennsylvania  17403-3651  None  None  None
# 2905                Ohio  44555-0001  None  None  None
# 2906       Massachusetts       01835  None  None  None
#
# [2907 rows x 6 columns]

# %%
university
# Out:
#                                                    name  \
# 0               A T Still University of Health Sciences
# 1                          Abilene Christian University
# 2                  Abraham Baldwin Agricultural College
# 3                                       Academy College
# 4                  Academy for Five Element Acupuncture
# ...                                                 ...
# 2902  Yo San University of Traditional Chinese Medicine
# 2903                                       York College
# 2904                          York College Pennsylvania
# 2905                        Youngstown State University
# 2906                                 Zion Bible College
#
#                                                 address  \
# 0           800 W Jefferson, Kirksville, Missouri 63501
# 1               1600 Campus Court, Abilene, Texas 79699
# 2            2802 Moore Hwy, Tifton, Georgia 31793-2601
# 3     1101 E. 78th Street, Suite 100, Minneapolis, M...
# ...

# %%
#  drop 
uni = university.drop(['address', 'Website', 'Type', 'street', 'city', 'state',
       'zip'], axis=1)
uni
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-26-452086bdbe14> in <module>
#       1 #  drop
#       2 uni = university.drop(['address', 'Website', 'Type', 'street', 'city', 'state',
# ----> 3        'zip'], axis=1)
#       4 uni
#
# ~/miniconda3/lib/python3.7/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3995             level=level,
#    3996             inplace=inplace,
# -> 3997             errors=errors,
#    3998         )
#    3999
#
# ~/miniconda3/lib/python3.7/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3934         for axis, labels in axes.items():
#    3935             if labels is not None:
# -> 3936                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3937
#    3938         if inplace:
#
# ...

# %%
# concat uni + addresses for mean + median by state 
# reference: data1 = pd.concat([data, names], axis=1)

bystate = pd.concat([uni, adresses2], axis =1)
bystate
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-27-391f5f4326a5> in <module>
#       2 # reference: data1 = pd.concat([data, names], axis=1)
#       3
# ----> 4 bystate = pd.concat([uni, adresses2], axis =1)
#       5 bystate
#
# NameError: name 'uni' is not defined

# %%
# drop zip-5
bystate2 = bystate.drop(['nnon','zip', 'non1', 'non2', 'non3'],axis=1)
bystate2

# %%
# mean by state 
state2 = bystate.groupby('state').mean()
state2

# %%
state2.head(60)

# %%
# median by state 
state3 = bystate.groupby('state').median()
state3

# %%
# mean by name 
name2 = bystate.groupby('name').mean()
name2

# %%
# median by name 
name3 = bystate.groupby('name').median()
name3

# %%
# Type - private or public 
unitype = university['Type']
type(unitype), unitype
# Out:
# (pandas.core.series.Series,
#  0                          4-year, Private not-for-profit
#  1                          4-year, Private not-for-profit
#  2                   4-year, primarily associate's, Public
#  3       4-year, primarily associate's, Private for-profit
#  4                          4-year, Private not-for-profit
#                                ...
#  2902                       4-year, Private not-for-profit
#  2903                       4-year, Private not-for-profit
#  2904                       4-year, Private not-for-profit
#  2905                                       4-year, Public
#  2906                       4-year, Private not-for-profit
#  Name: Type, Length: 2907, dtype: object)

# %%
unitype = unitype.str.split(',', expand=True)
unitype

# %%
university['Public'] = np.where(university['Type'].str.contains('Private')>0, 'Private', 'Public')
university
# Out:
#                                                    name  \
# 0               A T Still University of Health Sciences
# 1                          Abilene Christian University
# 2                  Abraham Baldwin Agricultural College
# 3                                       Academy College
# 4                  Academy for Five Element Acupuncture
# ...                                                 ...
# 2902  Yo San University of Traditional Chinese Medicine
# 2903                                       York College
# 2904                          York College Pennsylvania
# 2905                        Youngstown State University
# 2906                                 Zion Bible College
#
#                                                 address  \
# 0           800 W Jefferson, Kirksville, Missouri 63501
# 1               1600 Campus Court, Abilene, Texas 79699
# 2            2802 Moore Hwy, Tifton, Georgia 31793-2601
# 3     1101 E. 78th Street, Suite 100, Minneapolis, M...
# ...

# %%
university['For_profit'] = np.where(university.Type.str.contains(' for')>0, 'For-Profit', 'NFP')
university
# Out:
#                                                    name  \
# 0               A T Still University of Health Sciences
# 1                          Abilene Christian University
# 2                  Abraham Baldwin Agricultural College
# 3                                       Academy College
# 4                  Academy for Five Element Acupuncture
# ...                                                 ...
# 2902  Yo San University of Traditional Chinese Medicine
# 2903                                       York College
# 2904                          York College Pennsylvania
# 2905                        Youngstown State University
# 2906                                 Zion Bible College
#
#                                                 address  \
# 0           800 W Jefferson, Kirksville, Missouri 63501
# 1               1600 Campus Court, Abilene, Texas 79699
# 2            2802 Moore Hwy, Tifton, Georgia 31793-2601
# 3     1101 E. 78th Street, Suite 100, Minneapolis, M...
# ...

# %%
university['Primarily_Associates?'] = np.where(university.Type.str.contains('prim')>0 , 1, 0)
university
# Out:
#                                                    name  \
# 0               A T Still University of Health Sciences
# 1                          Abilene Christian University
# 2                  Abraham Baldwin Agricultural College
# 3                                       Academy College
# 4                  Academy for Five Element Acupuncture
# ...                                                 ...
# 2902  Yo San University of Traditional Chinese Medicine
# 2903                                       York College
# 2904                          York College Pennsylvania
# 2905                        Youngstown State University
# 2906                                 Zion Bible College
#
#                                                 address  \
# 0           800 W Jefferson, Kirksville, Missouri 63501
# 1               1600 Campus Court, Abilene, Texas 79699
# 2            2802 Moore Hwy, Tifton, Georgia 31793-2601
# 3     1101 E. 78th Street, Suite 100, Minneapolis, M...
# ...

# %%
university.groupby(['Public', 'Primarily_Associates?']).aggregate([np.mean, np.median])
# Out:
#                                        Size
#                                        mean  median
# Public  Primarily_Associates?
# Private 0                       2564.964444  1106.0
#         1                        982.177465   578.0
# Public  0                      11478.913765  7669.0
#         1                       6889.366197  3558.0

# %%
university.to_csv('uni', index=False)
